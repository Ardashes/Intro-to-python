# %%
import matplotlib.pyplot as plt
x=[0,10,20,30,40,50]
y=[0,20,40,60,80,100]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")          
plt.title("draw a line")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,4,0]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")          
plt.title("sample graph!")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,4,0]
x2=[1,2,3]
y2=[4,0,3]
plt.plot(x,y,label="line width 3",color="b",linewidth=3)
plt.plot(x2,y2,label="line width 5",color="r",linewidth=5)
plt.xlabel("x-axis")
plt.ylabel("y-axis") 
plt.legend()
plt.title("Two or more lines with different width and colours with suitable legends ")

plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,4,0]
x2=[1,2,3]
y2=[4,0,3]
plt.plot(x,y,label="line 1 dotted",color="b",linewidth=3,linestyle='dotted')
plt.plot(x2,y2,label="line 2 dashed",color="r",linewidth=5,linestyle='dashed')
plt.xlabel("x-axis")
plt.ylabel("y-axis") 
plt.legend()
plt.title("Two or more lines with different width and colours with suitable legends ")

plt.show()

# %%
import matplotlib.pyplot as plt

x2=[1,4,5,6,7]
y2=[2,6,3,6,3]

plt.plot(x2,y2,color="r",linestyle='dashed')
plt.xlabel("x-axis")
plt.ylabel("y-axis") 
plt.scatter(1,2,color='b',marker="o",s=200)
plt.scatter(4,6,color='b',marker="o",s=200)
plt.scatter(5,3,color='b',marker="o",s=200)
plt.scatter(6,6,color='b',marker="o",s=200)
plt.scatter(7,3,color='b',marker="o",s=200)


plt.title("display marker")

plt.show()

# %%
import csv

x = []
y = []

with open('test.txt', 'r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ',')
    for row in plots:
        #print(row)
        x.append(int(row[0]))
        y.append(int(row[1]))
plt.plot(x, y, label = 'loaded from file')
plt.title("sample graph")
plt.legend()
plt.show()

# %%
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
a=plt.bar(x,popularity)
plt.title("popularity of programming language oct 2017")
plt.xlabel("languages")
plt.ylabel("popularity")

plt.show()

# %%
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
a=plt.bar(x,popularity)
plt.title("popularity of programming language oct 2017")
plt.xlabel("languages")
plt.ylabel("popularity")
a[0].set_color('r')
a[1].set_color('black')
a[2].set_color('green')
a[3].set_color('blue')
a[4].set_color('yellow')
a[5].set_color('cyan')

plt.show()

# %%
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(x,popularity,color=("r","black",'green','blue','yellow','cyan'))
plt.title("popularity of programming language oct 2017")
plt.xlabel("languages")
plt.ylabel("popularity")


plt.show()

# %%
y=[31.3,24.8,12.4,11.3,10.8,9.4]
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
cols=["blue","orange","green","red","m",'grey']
plt.pie(y,labels=x,colors=cols,startangle=140,shadow=True,explode=(0.1,0,0,0,0,0),autopct="%1.1f%%")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randn(150)
y = np.random.randn(150)
plt.scatter(x, y,color="red")
plt.show()
